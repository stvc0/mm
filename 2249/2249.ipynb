# %%
import pandas as pd             # For data analysis 
import matplotlib.pyplot as plt # For barbell chart

# %%
raw = pd.read_excel('https://query.data.world/s/xhxxolzavwx7ds2ylfgjt7rzx4522q')

# %% [markdown]
# # Replicate the original visualization.

# %%
raw # The data is already order properly.
# Out:
#                                       Topic  True Proportion  \
# 0   Have a household income over $1 million             0.00
# 1                           Are transgender             0.01
# 2     Have a household income over $500,000             0.01
# 3                                Are Muslim             0.01
# 4                       Are Native American             0.01
# 5                                Are Jewish             0.02
# 6                     Live in New York City             0.03
# 7                        Are gay or lesbian             0.03
# 8                              Are atheists             0.03
# 9                              Are bisexual             0.04
# 10                   Are members of a union             0.04
# 11                  Are vegan or vegetarian             0.05
# 12                                Are Asian             0.06
# 13                   Are a military veteran             0.06
# 14                            Live in Texas             0.09
# 15                          Are left-handed             0.11
# 16                       Live in California             0.12
# 17                                Are Black             0.12
# 18                  Have an advanced degree             0.12
# 19          Are first-generation immigrants             0.14
# 20                             Are Hispanic             0.17
# 21                             Are Catholic             0.22
# 22                                Own a gun             0.32
# 23           Have at least a college degree             0.33
# 24    Have a household income over $100,000             0.34
# 25                          Have a passport             0.37
# 26                            Are Democrats             0.42
# 27                                Are obese             0.42
# 28                          Are Republicans             0.47
# 29                              Are married             0.51
# 30                  Have at least one child             0.57
# 31               Voted in the 2020 election             0.62
# 32     Have a household income over $50,000             0.62
# 33                                Are white             0.64
# 34                              Own a house             0.65
# 35    Are fully vaccinated against COVID-19             0.66
# 36                               Have a pet             0.67
# 37                            Are Christian             0.70
# 38        Have read a book in the past year             0.77
# 39     Have a household income over $25,000             0.82
# 40                  Have a driver's license             0.83
# 41                         Own a smartphone             0.85
# 42                    Have flown on a plane             0.88
# 43                                Own a car             0.88
# 44       Have at least a high school degree             0.89
#
#     Estimated Proportion
# 0                   0.20
# 1                   0.21
# 2                   0.26
# 3                   0.27
# 4                   0.27
# 5                   0.30
# 6                   0.30
# 7                   0.30
# 8                   0.33
# 9                   0.29
# 10                  0.36
# 11                  0.30
# 12                  0.29
# 13                  0.40
# 14                  0.30
# 15                  0.34
# 16                  0.32
# 17                  0.41
# 18                  0.37
# 19                  0.33
# 20                  0.39
# 21                  0.41
# 22                  0.54
# 23                  0.47
# 24                  0.38
# 25                  0.45
# 26                  0.51
# 27                  0.56
# 28                  0.50
# 29                  0.55
# 30                  0.58
# 31                  0.61
# 32                  0.50
# 33                  0.59
# 34                  0.49
# 35                  0.59
# 36                  0.62
# 37                  0.58
# 38                  0.50
# 39                  0.62
# 40                  0.68
# 41                  0.76
# 42                  0.59
# 43                  0.66
# 44                  0.65

# %%
# Want beginning and ending values. 
x_min = raw['True Proportion']
x_max = raw['Estimated Proportion']

# y values will be increasing b y 1 for each item 
y = range(0, len(raw))

# %%
plt.hlines(y, xmin = x_min, xmax = x_max)
